# %%
# !pip install -q --upgrade tensorflow
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# tensorflow-decision-forests 1.8.1 requires tensorflow~=2.15.0, but you have tensorflow 2.16.2 which is incompatible.
# tensorflow-text 2.15.0 requires tensorflow<2.16,>=2.15.0; platform_machine != "arm64" or platform_system != "Darwin", but you have tensorflow 2.16.2 which is incompatible.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.16.2 which is incompatible.

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import random
import numpy as np
from glob import glob
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

import keras
from keras import layers

import tensorflow as tf
# Out:
# 2024-07-10 08:41:10.029245: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-10 08:41:10.054386: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-10 08:41:10.054427: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# !wget https://huggingface.co/datasets/geekyrakshit/LoL-Dataset/resolve/main/lol_dataset.zip
# !unzip -q lol_dataset.zip && rm lol_dataset.zip
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# --2024-07-10 08:41:16--  https://huggingface.co/datasets/geekyrakshit/LoL-Dataset/resolve/main/lol_dataset.zip
# Resolving huggingface.co (huggingface.co)... 3.163.189.114, 3.163.189.90, 3.163.189.74, ...
# Connecting to huggingface.co (huggingface.co)|3.163.189.114|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/d9/09/d909ef7668bb417b7065a311bd55a3084cc83a1f918e13cb41c5503328432db2/419fddc48958cd0f5599939ee0248852a37ceb8bb738c9b9525e95b25a89de9a?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27lol_dataset.zip%3B+filename%3D%22lol_dataset.zip%22%3B&response-content-type=application%2Fzip&Expires=1720860076&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=LscHoHGBOPWVsSrYjyeV9o4X9M5TrvOjKiV6-N9l7VlUXlCky7dVkBOklmszTTzQfd9pVVkMpH3qlZtaIRnJhK4nQaXN6NKkR3VEK8BJ8TGdWH2slxb-pZwC49BvO2fRTS7GTjUhadIEbxPck2N4b7%7E%7E28ET54El4QfMy-A5aoDlVM6NZ90k%7EY%7EsMbrDWTIq0pAa9P-hXOR5GnMyuU%7EPPwfxvVb5OzzkyNXJ1Dn9eQlKe2R32vPRdrL%7EUMJIS7Png4qqGc8r%7EGuhRsyfRHC7tUk5U21y8npLuH7nIS6b9-oXYM3Jsz5YAUa%7EpY95sM9I5KaaXpaHFxfO3gw53xJjfw__&Key-Pair-Id=K3ESJI6DHPFC7 [following]
# --2024-07-10 08:41:16--  https://cdn-lfs.huggingface.co/repos/d9/09/d909ef7668bb417b7065a311bd55a3084cc83a1f918e13cb41c5503328432db2/419fddc48958cd0f5599939ee0248852a37ceb8bb738c9b9525e95b25a89de9a?response-content-disposition=inline%3B+filename*%3DUTF-8''lol_dataset.zip%3B+filename%3D%22lol_dataset.zip%22%3B&response-content-type=application%2Fzip&Expires=1720860076&Policy=~cmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=LscHoHGBOPWVsSrYjyeV9o4X9M5TrvOjKiV6-N9l7VlUXlCky7dVkBOklmszTTzQfd9pVVkMpH3qlZtaIRnJhK4nQaXN6NKkR3VEK8BJ8TGdWH2slxb-pZwC49BvO2fRTS7GTjUhadIEbxPck2N4b7~~28ET54El4QfMy-A5aoDlVM6NZ90k~Y~sMbrDWTIq0pAa9P-hXOR5GnMyuU~PPwfxvVb5OzzkyNXJ1Dn9eQlKe2R32vPRdrL~UMJIS7Png4qqGc8r~GuhRsyfRHC7tUk5U21y8npLuH7nIS6b9-oXYM3Jsz5YAUa~pY95sM9I5KaaXpaHFxfO3gw53xJjfw__&Key-Pair-Id=K3ESJI6DHPFC7
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 108.138.94.23, 108.138.94.25, 108.138.94.122, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|108.138.94.23|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 347171015 (331M) [application/zip]
# Saving to: 'lol_dataset.zip'
#
# lol_dataset.zip     100%[===================>] 331.09M  22.8MB/s    in 38s
#
# 2024-07-10 08:41:54 (8.75 MB/s) - 'lol_dataset.zip' saved [347171015/347171015]

# %%
random.seed(10)

IMAGE_SIZE = 128
BATCH_SIZE = 4
MAX_TRAIN_IMAGES = 300


def read_image(image_path):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels=3)
    image.set_shape([None, None, 3])
    image = tf.cast(image, dtype=tf.float32) / 255.0
    return image


def random_crop(low_image, enhanced_image):
    low_image_shape = tf.shape(low_image)[:2]
    low_w = tf.random.uniform(
        shape=(), maxval=low_image_shape[1] - IMAGE_SIZE + 1, dtype=tf.int32
    )
    low_h = tf.random.uniform(
        shape=(), maxval=low_image_shape[0] - IMAGE_SIZE + 1, dtype=tf.int32
    )
    low_image_cropped = low_image[
        low_h : low_h + IMAGE_SIZE, low_w : low_w + IMAGE_SIZE
    ]
    enhanced_image_cropped = enhanced_image[
        low_h : low_h + IMAGE_SIZE, low_w : low_w + IMAGE_SIZE
    ]
    # in order to avoid `NONE` during shape inference
    low_image_cropped.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    enhanced_image_cropped.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    return low_image_cropped, enhanced_image_cropped


def load_data(low_light_image_path, enhanced_image_path):
    low_light_image = read_image(low_light_image_path)
    enhanced_image = read_image(enhanced_image_path)
    low_light_image, enhanced_image = random_crop(low_light_image, enhanced_image)
    return low_light_image, enhanced_image


def get_dataset(low_light_images, enhanced_images):
    dataset = tf.data.Dataset.from_tensor_slices((low_light_images, enhanced_images))
    dataset = dataset.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
    return dataset


train_low_light_images = sorted(glob("./lol_dataset/our485/low/*"))[:MAX_TRAIN_IMAGES]
train_enhanced_images = sorted(glob("./lol_dataset/our485/high/*"))[:MAX_TRAIN_IMAGES]

val_low_light_images = sorted(glob("./lol_dataset/our485/low/*"))[MAX_TRAIN_IMAGES:]
val_enhanced_images = sorted(glob("./lol_dataset/our485/high/*"))[MAX_TRAIN_IMAGES:]

test_low_light_images = sorted(glob("./lol_dataset/eval15/low/*"))
test_enhanced_images = sorted(glob("./lol_dataset/eval15/high/*"))


train_dataset = get_dataset(train_low_light_images, train_enhanced_images)
val_dataset = get_dataset(val_low_light_images, val_enhanced_images)


print("Train Dataset:", train_dataset.element_spec)
print("Val Dataset:", val_dataset.element_spec)
# Out:
# Train Dataset: (TensorSpec(shape=(4, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(4, 128, 128, 3), dtype=tf.float32, name=None))
# Val Dataset: (TensorSpec(shape=(4, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(4, 128, 128, 3), dtype=tf.float32, name=None))

# %%
def selective_kernel_feature_fusion(
    multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3
):
    channels = list(multi_scale_feature_1.shape)[-1]
    combined_feature = layers.Add()(
        [multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3]
    )
    gap = layers.GlobalAveragePooling2D()(combined_feature)
    channel_wise_statistics = layers.Reshape((1, 1, channels))(gap)
    compact_feature_representation = layers.Conv2D(
        filters=channels // 8, kernel_size=(1, 1), activation="relu"
    )(channel_wise_statistics)
    feature_descriptor_1 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_descriptor_2 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_descriptor_3 = layers.Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_1 = multi_scale_feature_1 * feature_descriptor_1
    feature_2 = multi_scale_feature_2 * feature_descriptor_2
    feature_3 = multi_scale_feature_3 * feature_descriptor_3
    aggregated_feature = layers.Add()([feature_1, feature_2, feature_3])
    return aggregated_feature

# %%
class ChannelPooling(layers.Layer):
    def __init__(self, axis=-1, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.axis = axis
        self.concat = layers.Concatenate(axis=self.axis)

    def call(self, inputs):
        average_pooling = tf.expand_dims(tf.reduce_mean(inputs, axis=-1), axis=-1)
        max_pooling = tf.expand_dims(tf.reduce_max(inputs, axis=-1), axis=-1)
        return self.concat([average_pooling, max_pooling])

    def get_config(self):
        config = super().get_config()
        config.update({"axis": self.axis})


def spatial_attention_block(input_tensor):
    compressed_feature_map = ChannelPooling(axis=-1)(input_tensor)
    feature_map = layers.Conv2D(1, kernel_size=(1, 1))(compressed_feature_map)
    feature_map = keras.activations.sigmoid(feature_map)
    return input_tensor * feature_map


def channel_attention_block(input_tensor):
    channels = list(input_tensor.shape)[-1]
    average_pooling = layers.GlobalAveragePooling2D()(input_tensor)
    feature_descriptor = layers.Reshape((1, 1, channels))(average_pooling)
    feature_activations = layers.Conv2D(
        filters=channels // 8, kernel_size=(1, 1), activation="relu"
    )(feature_descriptor)
    feature_activations = layers.Conv2D(
        filters=channels, kernel_size=(1, 1), activation="sigmoid"
    )(feature_activations)
    return input_tensor * feature_activations


def dual_attention_unit_block(input_tensor):
    channels = list(input_tensor.shape)[-1]
    feature_map = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(input_tensor)
    feature_map = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(
        feature_map
    )
    channel_attention = channel_attention_block(feature_map)
    spatial_attention = spatial_attention_block(feature_map)
    concatenation = layers.Concatenate(axis=-1)([channel_attention, spatial_attention])
    concatenation = layers.Conv2D(channels, kernel_size=(1, 1))(concatenation)
    return layers.Add()([input_tensor, concatenation])

# %%
def down_sampling_module(input_tensor):
    channels = list(input_tensor.shape)[-1]
    main_branch = layers.Conv2D(channels, kernel_size=(1, 1), activation="relu")(
        input_tensor
    )
    main_branch = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(main_branch)
    main_branch = layers.MaxPooling2D()(main_branch)
    main_branch = layers.Conv2D(channels * 2, kernel_size=(1, 1))(main_branch)
    skip_branch = layers.MaxPooling2D()(input_tensor)
    skip_branch = layers.Conv2D(channels * 2, kernel_size=(1, 1))(skip_branch)
    return layers.Add()([skip_branch, main_branch])


def up_sampling_module(input_tensor):
    channels = list(input_tensor.shape)[-1]
    main_branch = layers.Conv2D(channels, kernel_size=(1, 1), activation="relu")(
        input_tensor
    )
    main_branch = layers.Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(main_branch)
    main_branch = layers.UpSampling2D()(main_branch)
    main_branch = layers.Conv2D(channels // 2, kernel_size=(1, 1))(main_branch)
    skip_branch = layers.UpSampling2D()(input_tensor)
    skip_branch = layers.Conv2D(channels // 2, kernel_size=(1, 1))(skip_branch)
    return layers.Add()([skip_branch, main_branch])


# MRB Block
def multi_scale_residual_block(input_tensor, channels):
    # features
    level1 = input_tensor
    level2 = down_sampling_module(input_tensor)
    level3 = down_sampling_module(level2)
    # DAU
    level1_dau = dual_attention_unit_block(level1)
    level2_dau = dual_attention_unit_block(level2)
    level3_dau = dual_attention_unit_block(level3)
    # SKFF
    level1_skff = selective_kernel_feature_fusion(
        level1_dau,
        up_sampling_module(level2_dau),
        up_sampling_module(up_sampling_module(level3_dau)),
    )
    level2_skff = selective_kernel_feature_fusion(
        down_sampling_module(level1_dau),
        level2_dau,
        up_sampling_module(level3_dau),
    )
    level3_skff = selective_kernel_feature_fusion(
        down_sampling_module(down_sampling_module(level1_dau)),
        down_sampling_module(level2_dau),
        level3_dau,
    )
    # DAU 2
    level1_dau_2 = dual_attention_unit_block(level1_skff)
    level2_dau_2 = up_sampling_module((dual_attention_unit_block(level2_skff)))
    level3_dau_2 = up_sampling_module(
        up_sampling_module(dual_attention_unit_block(level3_skff))
    )
    # SKFF 2
    skff_ = selective_kernel_feature_fusion(level1_dau_2, level2_dau_2, level3_dau_2)
    conv = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(skff_)
    return layers.Add()([input_tensor, conv])

# %%
def recursive_residual_group(input_tensor, num_mrb, channels):
    conv1 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(input_tensor)
    for _ in range(num_mrb):
        conv1 = multi_scale_residual_block(conv1, channels)
    conv2 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(conv1)
    return layers.Add()([conv2, input_tensor])


def mirnet_model(num_rrg, num_mrb, channels):
    input_tensor = keras.Input(shape=[None, None, 3])
    x1 = layers.Conv2D(channels, kernel_size=(3, 3), padding="same")(input_tensor)
    for _ in range(num_rrg):
        x1 = recursive_residual_group(x1, num_mrb, channels)
    conv = layers.Conv2D(3, kernel_size=(3, 3), padding="same")(x1)
    output_tensor = layers.Add()([input_tensor, conv])
    return keras.Model(input_tensor, output_tensor)


model = mirnet_model(num_rrg=3, num_mrb=2, channels=64)

# %%
def charbonnier_loss(y_true, y_pred):
    return tf.reduce_mean(tf.sqrt(tf.square(y_true - y_pred) + tf.square(1e-3)))


def peak_signal_noise_ratio(y_true, y_pred):
    return tf.image.psnr(y_pred, y_true, max_val=255.0)


optimizer = keras.optimizers.Adam(learning_rate=1e-4)
model.compile(
    optimizer=optimizer,
    loss=charbonnier_loss,
    metrics=[peak_signal_noise_ratio],
)

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=50,
    callbacks=[
        keras.callbacks.ReduceLROnPlateau(
            monitor="val_peak_signal_noise_ratio",
            factor=0.5,
            patience=5,
            verbose=1,
            min_delta=1e-7,
            mode="max",
        )
    ],
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1720601089.982490     115 service.cc:145] XLA service 0x78e1c8004680 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1720601089.982552     115 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1720601089.982558     115 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# W0000 00:00:1720601102.985024     115 assert_op.cc:38] Ignoring Assert operator PSNR/Assert/Assert
# W0000 00:00:1720601102.985169     115 assert_op.cc:38] Ignoring Assert operator PSNR/Assert_1/Assert
# I0000 00:00:1720601239.247534     115 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 825ms/step - loss: 0.2093 - peak_signal_noise_ratio: 61.7011
# W0000 00:00:1720601315.291042     115 assert_op.cc:38] Ignoring Assert operator PSNR/Assert/Assert
# W0000 00:00:1720601315.291131     115 assert_op.cc:38] Ignoring Assert operator PSNR/Assert_1/Assert
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 404s 1s/step - loss: 0.2091 - peak_signal_noise_ratio: 61.7073 - val_loss: 0.1277 - val_peak_signal_noise_ratio: 65.5677 - learning_rate: 1.0000e-04
# Epoch 2/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 75s 998ms/step - loss: 0.1648 - peak_signal_noise_ratio: 63.6337 - val_loss: 0.1219 - val_peak_signal_noise_ratio: 65.7725 - learning_rate: 1.0000e-04
# Epoch 3/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 75s 996ms/step - loss: 0.1557 - peak_signal_noise_ratio: 64.0070 - val_loss: 0.1200 - val_peak_signal_noise_ratio: 66.0349 - learning_rate: 1.0000e-04
# Epoch 4/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 75s 996ms/step - loss: 0.1620 - peak_signal_noise_ratio: 63.7587 - val_loss: 0.1172 - val_peak_signal_noise_ratio: 66.2055 - learning_rate: 1.0000e-04
# Epoch 5/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 75s 996ms/step - loss: 0.1500 - peak_signal_noise_ratio: 64.3418 - val_loss: 0.1158 - val_peak_signal_noise_ratio: 66.4742 - learning_rate: 1.0000e-04
# Epoch 6/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 75s 995ms/step - loss: 0.1573 - peak_signal_noise_ratio: 64.1365 - val_loss: 0.1227 - val_peak_signal_noise_ratio: 65.9433 - learning_rate: 1.0000e-04
# Epoch 7/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 993ms/step - loss: 0.1537 - peak_signal_noise_ratio: 64.2191 - val_loss: 0.1266 - val_peak_signal_noise_ratio: 65.8426 - learning_rate: 1.0000e-04
# Epoch 8/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.1653 - peak_signal_noise_ratio: 63.6695 - val_loss: 0.1199 - val_peak_signal_noise_ratio: 66.2564 - learning_rate: 1.0000e-04
# Epoch 9/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 75s 996ms/step - loss: 0.1561 - peak_signal_noise_ratio: 64.0167 - val_loss: 0.1135 - val_peak_signal_noise_ratio: 67.0453 - learning_rate: 1.0000e-04
# Epoch 10/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 993ms/step - loss: 0.1637 - peak_signal_noise_ratio: 64.3481 - val_loss: 0.1194 - val_peak_signal_noise_ratio: 66.3653 - learning_rate: 1.0000e-04
# Epoch 11/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 991ms/step - loss: 0.1533 - peak_signal_noise_ratio: 64.5717 - val_loss: 0.1186 - val_peak_signal_noise_ratio: 66.6991 - learning_rate: 1.0000e-04
# Epoch 12/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 991ms/step - loss: 0.1614 - peak_signal_noise_ratio: 63.9160 - val_loss: 0.1137 - val_peak_signal_noise_ratio: 67.0754 - learning_rate: 1.0000e-04
# Epoch 13/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 991ms/step - loss: 0.1445 - peak_signal_noise_ratio: 64.8758 - val_loss: 0.1084 - val_peak_signal_noise_ratio: 67.1554 - learning_rate: 1.0000e-04
# Epoch 14/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 989ms/step - loss: 0.1485 - peak_signal_noise_ratio: 64.7227 - val_loss: 0.1180 - val_peak_signal_noise_ratio: 66.6616 - learning_rate: 1.0000e-04
# Epoch 15/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 989ms/step - loss: 0.1536 - peak_signal_noise_ratio: 64.4223 - val_loss: 0.1167 - val_peak_signal_noise_ratio: 66.9468 - learning_rate: 1.0000e-04
# Epoch 16/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 990ms/step - loss: 0.1491 - peak_signal_noise_ratio: 64.7561 - val_loss: 0.1144 - val_peak_signal_noise_ratio: 67.1324 - learning_rate: 1.0000e-04
# Epoch 17/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 989ms/step - loss: 0.1428 - peak_signal_noise_ratio: 65.2244 - val_loss: 0.1103 - val_peak_signal_noise_ratio: 67.2822 - learning_rate: 1.0000e-04
# Epoch 18/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 989ms/step - loss: 0.1429 - peak_signal_noise_ratio: 65.0664 - val_loss: 0.1108 - val_peak_signal_noise_ratio: 67.1116 - learning_rate: 1.0000e-04
# Epoch 19/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 991ms/step - loss: 0.1393 - peak_signal_noise_ratio: 65.3176 - val_loss: 0.1074 - val_peak_signal_noise_ratio: 67.3399 - learning_rate: 1.0000e-04
# Epoch 20/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 989ms/step - loss: 0.1532 - peak_signal_noise_ratio: 64.7025 - val_loss: 0.1061 - val_peak_signal_noise_ratio: 67.6466 - learning_rate: 1.0000e-04
# Epoch 21/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 991ms/step - loss: 0.1455 - peak_signal_noise_ratio: 65.1246 - val_loss: 0.1083 - val_peak_signal_noise_ratio: 67.3387 - learning_rate: 1.0000e-04
# Epoch 22/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 989ms/step - loss: 0.1424 - peak_signal_noise_ratio: 65.2257 - val_loss: 0.1067 - val_peak_signal_noise_ratio: 67.6771 - learning_rate: 1.0000e-04
# Epoch 23/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 989ms/step - loss: 0.1462 - peak_signal_noise_ratio: 64.9987 - val_loss: 0.1071 - val_peak_signal_noise_ratio: 67.4331 - learning_rate: 1.0000e-04
# Epoch 24/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 988ms/step - loss: 0.1298 - peak_signal_noise_ratio: 65.8224 - val_loss: 0.1093 - val_peak_signal_noise_ratio: 67.3764 - learning_rate: 1.0000e-04
# Epoch 25/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 990ms/step - loss: 0.1443 - peak_signal_noise_ratio: 65.2399 - val_loss: 0.1007 - val_peak_signal_noise_ratio: 68.0486 - learning_rate: 1.0000e-04
# Epoch 26/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 990ms/step - loss: 0.1390 - peak_signal_noise_ratio: 65.5005 - val_loss: 0.1047 - val_peak_signal_noise_ratio: 67.9417 - learning_rate: 1.0000e-04
# Epoch 27/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.1337 - peak_signal_noise_ratio: 65.6631 - val_loss: 0.1009 - val_peak_signal_noise_ratio: 67.8999 - learning_rate: 1.0000e-04
# Epoch 28/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 991ms/step - loss: 0.1324 - peak_signal_noise_ratio: 66.0829 - val_loss: 0.1022 - val_peak_signal_noise_ratio: 67.9516 - learning_rate: 1.0000e-04
# Epoch 29/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 991ms/step - loss: 0.1259 - peak_signal_noise_ratio: 66.4806 - val_loss: 0.1005 - val_peak_signal_noise_ratio: 67.9392 - learning_rate: 1.0000e-04
# Epoch 30/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 843ms/step - loss: 0.1260 - peak_signal_noise_ratio: 66.3309
# Epoch 30: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 990ms/step - loss: 0.1260 - peak_signal_noise_ratio: 66.3305 - val_loss: 0.1069 - val_peak_signal_noise_ratio: 67.6275 - learning_rate: 1.0000e-04
# Epoch 31/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 992ms/step - loss: 0.1321 - peak_signal_noise_ratio: 66.1162 - val_loss: 0.1085 - val_peak_signal_noise_ratio: 67.1465 - learning_rate: 5.0000e-05
# Epoch 32/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 991ms/step - loss: 0.1289 - peak_signal_noise_ratio: 66.1979 - val_loss: 0.1124 - val_peak_signal_noise_ratio: 66.8100 - learning_rate: 5.0000e-05
# Epoch 33/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 991ms/step - loss: 0.1215 - peak_signal_noise_ratio: 66.4423 - val_loss: 0.1046 - val_peak_signal_noise_ratio: 67.6179 - learning_rate: 5.0000e-05
# Epoch 34/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 992ms/step - loss: 0.1219 - peak_signal_noise_ratio: 66.6064 - val_loss: 0.1088 - val_peak_signal_noise_ratio: 67.1918 - learning_rate: 5.0000e-05
# Epoch 35/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 844ms/step - loss: 0.1155 - peak_signal_noise_ratio: 67.0173
# Epoch 35: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 992ms/step - loss: 0.1156 - peak_signal_noise_ratio: 67.0144 - val_loss: 0.1045 - val_peak_signal_noise_ratio: 67.4283 - learning_rate: 5.0000e-05
# Epoch 36/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 991ms/step - loss: 0.1195 - peak_signal_noise_ratio: 66.9350 - val_loss: 0.1077 - val_peak_signal_noise_ratio: 67.1512 - learning_rate: 2.5000e-05
# Epoch 37/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 991ms/step - loss: 0.1161 - peak_signal_noise_ratio: 67.0620 - val_loss: 0.1108 - val_peak_signal_noise_ratio: 67.1084 - learning_rate: 2.5000e-05
# Epoch 38/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 992ms/step - loss: 0.1132 - peak_signal_noise_ratio: 67.3101 - val_loss: 0.1066 - val_peak_signal_noise_ratio: 67.3383 - learning_rate: 2.5000e-05
# Epoch 39/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 992ms/step - loss: 0.1196 - peak_signal_noise_ratio: 66.8544 - val_loss: 0.1034 - val_peak_signal_noise_ratio: 67.6977 - learning_rate: 2.5000e-05
# Epoch 40/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 842ms/step - loss: 0.1154 - peak_signal_noise_ratio: 67.0427
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 989ms/step - loss: 0.1153 - peak_signal_noise_ratio: 67.0461 - val_loss: 0.1103 - val_peak_signal_noise_ratio: 67.0568 - learning_rate: 2.5000e-05
# Epoch 41/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 991ms/step - loss: 0.1120 - peak_signal_noise_ratio: 67.1865 - val_loss: 0.1093 - val_peak_signal_noise_ratio: 67.4251 - learning_rate: 1.2500e-05
# Epoch 42/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.1092 - peak_signal_noise_ratio: 67.4924 - val_loss: 0.1066 - val_peak_signal_noise_ratio: 67.5093 - learning_rate: 1.2500e-05
# Epoch 43/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 990ms/step - loss: 0.1079 - peak_signal_noise_ratio: 67.6643 - val_loss: 0.1024 - val_peak_signal_noise_ratio: 67.8936 - learning_rate: 1.2500e-05
# Epoch 44/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 990ms/step - loss: 0.1083 - peak_signal_noise_ratio: 67.6174 - val_loss: 0.1087 - val_peak_signal_noise_ratio: 67.4041 - learning_rate: 1.2500e-05
# Epoch 45/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 841ms/step - loss: 0.1091 - peak_signal_noise_ratio: 67.4012
# Epoch 45: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 989ms/step - loss: 0.1091 - peak_signal_noise_ratio: 67.4016 - val_loss: 0.1093 - val_peak_signal_noise_ratio: 67.4767 - learning_rate: 1.2500e-05
# Epoch 46/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 988ms/step - loss: 0.1053 - peak_signal_noise_ratio: 67.7906 - val_loss: 0.1054 - val_peak_signal_noise_ratio: 67.6685 - learning_rate: 6.2500e-06
# Epoch 47/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 991ms/step - loss: 0.1032 - peak_signal_noise_ratio: 68.0459 - val_loss: 0.1058 - val_peak_signal_noise_ratio: 67.6883 - learning_rate: 6.2500e-06
# Epoch 48/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 991ms/step - loss: 0.1137 - peak_signal_noise_ratio: 67.3666 - val_loss: 0.1076 - val_peak_signal_noise_ratio: 67.6705 - learning_rate: 6.2500e-06
# Epoch 49/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 991ms/step - loss: 0.1181 - peak_signal_noise_ratio: 67.1265 - val_loss: 0.1040 - val_peak_signal_noise_ratio: 67.8725 - learning_rate: 6.2500e-06
# Epoch 50/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 845ms/step - loss: 0.1122 - peak_signal_noise_ratio: 67.4920
# Epoch 50: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 74s 992ms/step - loss: 0.1121 - peak_signal_noise_ratio: 67.4938 - val_loss: 0.1078 - val_peak_signal_noise_ratio: 67.4212 - learning_rate: 6.2500e-06

# %%
def plot_history(value, name):
    plt.plot(history.history[value], label=f"train_{name.lower()}")
    plt.plot(history.history[f"val_{value}"], label=f"val_{name.lower()}")
    plt.xlabel("Epochs")
    plt.ylabel(name)
    plt.title(f"Train and Validation {name} Over Epochs", fontsize=14)
    plt.legend()
    plt.grid()
    plt.show()


plot_history("loss", "Loss")
plot_history("peak_signal_noise_ratio", "PSNR")

# %%
def plot_results(images, titles, figure_size=(12, 12)):
    fig = plt.figure(figsize=figure_size)
    for i in range(len(images)):
        fig.add_subplot(1, len(images), i + 1).set_title(titles[i])
        _ = plt.imshow(images[i])
        plt.axis("off")
    plt.show()


def infer(original_image):
    image = keras.utils.img_to_array(original_image)
    image = image.astype("float32") / 255.0
    image = np.expand_dims(image, axis=0)
    output = model.predict(image, verbose=0)
    output_image = output[0] * 255.0
    output_image = output_image.clip(0, 255)
    output_image = output_image.reshape(
        (np.shape(output_image)[0], np.shape(output_image)[1], 3)
    )
    output_image = Image.fromarray(np.uint8(output_image))
    original_image = Image.fromarray(np.uint8(original_image))
    return output_image

# %%
for low_light_image in random.sample(test_low_light_images, 6):
    original_image = Image.open(low_light_image)
    enhanced_image = infer(original_image)
    plot_results(
        [original_image, ImageOps.autocontrast(original_image), enhanced_image],
        ["Original", "PIL Autocontrast", "MIRNet Enhanced"],
        (20, 12),
    )
